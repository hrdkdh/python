# %%
import pandas as pd

df = pd.read_excel("gv_m_pop-.xlsx")

# %%
df
# Out:
#        시군구코드  시군구명  WGS84좌표, X좌표값  WGS84좌표, Y좌표값    조사일시          월요일  \
# 0      41220   평택시     126.969610      37.045124  201509     0.025304
# 1      11350   노원구     127.060340      37.639175  201509    97.232959
# 2      11560  영등포구     126.939010      37.520008  201509  2032.897143
# 3      41150  의정부시     127.040050      37.737648  201509     0.027465
# 4      11140    중구     126.974600      37.561170  201509   514.638239
# ...      ...   ...            ...            ...     ...          ...
# 11640  11305   강북구     127.014595      37.640910  201509   143.163110
# 11641  11560  영등포구     126.903915      37.516960  201509    83.591698
# 11642  11140    중구     126.974945      37.558850  201509  4692.153086
# 11643  11500   강서구     126.806984      37.563343  201509   116.581136
# 11644  11740   강동구     127.167076      37.552060  201509   276.674432
#
#                화요일          수요일          목요일          금요일  ...          14시  \
# ...

# %%
df.columns
# Out:
# Index(['시군구코드', '시군구명', 'WGS84좌표, X좌표값', 'WGS84좌표, Y좌표값', '조사일시', '월요일', '화요일',
#        '수요일', '목요일', '금요일', '토요일', '일요일', '1~14세', '15~19세', '20~24세',
#        '25~29세', '30~34세', '35~39세', '40~44세', '45~49세', '50~54세', '55~59세',
#        '60세이상', '1~14세.1', '15~19세.1', '20~24세.1', '25~29세.1', '30~34세.1',
#        '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1', '60세이상.1',
#        '0시', '1시', '2시', '3시', '4시', '5시', '6시', '7시', '8시', '9시', '10시',
#        '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시',
#        '21시', '22시', '23시'],
#       dtype='object')

# %%
df["시군구명"].unique()
# Out:
# array(['평택시', '노원구', '영등포구', '의정부시', '중구', '서초구', '시흥시', '수원시 권선구',
#        '성남시 수정구', '도봉구', '화성시', '수원시 영통구', '동작구', '양천구', '강서구', '포천시',
#        '동대문구', '송파구', '강남구', '구로구', '용인시기흥구', '성동구', '부천시원미구', '남양주시',
#        '양주시', '서구', '의왕시', '계양구', '성남시 중원구', '동구', '광명시', '연수구', '금천구',
#        '수원시 장안구', '양평군', '안양시동안구', '수원시 팔달구', '안양시만안구', '광진구', '은평구',
#        '관악구', '용인시처인구', '종로구', '마포구', '이천시', '부천시오정구', '중랑구', '부평구',
#        '용산구', '남구', '고양시일산동구', '서대문구', '용인시수지구', '오산시', '성북구', '남동구',
#        '옹진군', '하남시', '강동구', '성남시 분당구', '고양시덕양구', '가평군', '구리시', '부천시소사구',
#        '안산시상록구', '안성시', '강화군', '고양시일산서구', '군포시', '파주시', '안산시단원구', '광주시',
#        '과천시', '강북구', '여주시', '연천군', '김포시', '동두천시'], dtype=object)

# %%
df.sort_values(by="19시")
# Out:
#       시군구코드     시군구명  WGS84좌표, X좌표값  WGS84좌표, Y좌표값    조사일시          월요일  \
# 1591  11680      강남구     127.058180      37.507812  201509      0.00000
# 6731  11170      용산구     126.971504      37.542290  201509      0.00000
# 1782  41131  성남시 수정구     127.129720      37.435290  201509      0.00000
# 4334  11680      강남구     127.057550      37.510597  201509      0.00000
# 401   11680      강남구     127.036804      37.509950  201509      0.00000
# ...     ...      ...            ...            ...     ...          ...
# 4644  41135  성남시 분당구     127.125930      37.386425  201509  31484.00000
# 7421  41131  성남시 수정구     127.129000      37.435535  201509  28292.00000
# 6303  28200      남동구     126.738304      37.400635  201509  28421.25229
# 9461  41195   부천시원미구     126.752270      37.504160  201509  31598.00000
# 591   41450      하남시     127.203210      37.540554  201509  39404.18182
#
#                화요일           수요일           목요일           금요일  ...  \
# ...
